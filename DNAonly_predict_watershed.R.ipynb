# %%
library(optparse)
library(arrow)
library(data.table)
library(dplyr)
library(yaml)

source("watershed.R")
# Out:
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/config.yaml', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet.done', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet.done', "featureset_config" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/config.yaml', "data_pq" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet', "data_pq_done" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet.done', "subset_pq" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet', "subset_pq_done" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet.done'),
    output = list('/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/train.parquet', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/test.parquet', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/model.joblib', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/features.yaml', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/done', "train_data_dir" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/train.parquet', "test_data_dir" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/test.parquet', "model_joblib" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/model.joblib', "features_yaml" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/features.yaml', "touch_file" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/done'),
    params = list('/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/feature_sets', '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models', 'train_simplecv.py', "output_basedir" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm', "feature_dir" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/feature_sets', "model_dir" = '/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models', "nb_script" = 'train_simplecv.py'),
    wildcards = list('gtex_v8_old_dna', 'dna_only', 'watershed', 'lightgbm', "ds_dir" = 'gtex_v8_old_dna', "subset" = 'dna_only', "feature_set" = 'watershed', "model_type" = 'lightgbm'),
    threads = 1,
    log = list(),
    resources = list('tmpdir', 'ntasks', 'mem_mb', 'mem_mib', "tmpdir" = '/scratch/tmp/hoelzlwi', "ntasks" = 1, "mem_mb" = 120000, "mem_mib" = 114441),
    config = list("projectTitle" = 'REP', "n_splits" = 6, "dirs" = list("CACHE_DIR" = '/s/project/rep/cache', "RAW_DATA_DIR" = '/s/project/rep/raw', "PROCESSED_DATA_DIR" = '/s/project/rep/processed', "MODEL_DIR" = '/s/project/rep/processed/training_results_v14'), "canonical_transcript_pq" = '/s/project/rep/processed/training_results_v14/general/gtex_canonical_transcript.parquet', "expressed_genes_pq" = '/s/project/rep/processed/training_results_v14/gtex_v8/gene_is_expressed_per_subtissue.parquet', "system" = list("MANE_select_url" = 'https://ftp.ncbi.nlm.nih.gov/refseq/MANE/MANE_human/release_1.2/MANE.GRCh38.v1.2.ensembl_genomic.gtf.gz', "gencode_basepath" = '/s/genomes/Gencode/Gencode_human/release_{gencode_version}', "vep" = list("version" = 108, "vep_bin" = 'vep', "perl_bin" = 'perl', "vep_cache_dir" = '/s/raw/vep/{vep_version}', "cadd_dir" = '/s/raw/cadd/v1.6/{human_genome_assembly}', "loftee_data_dir" = '/s/raw/loftee/{human_genome_assembly}', "loftee_src_path" = '/s/raw/loftee/{human_genome_assembly}_src'), "absplice" = list("cache" = c('/s/project/rep/processed/absplice_cache/{human_genome_version}/veff.snp.parquet')))),
    rule = 'models__train_simplecv',
    bench_iteration = as.numeric(NA),
    scriptdir = '/data/nasif12/home_if12/hoelzlwi/Projects/REP/rep_scripts/smk/ds_dir/models',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)


######## snakemake preamble end #########

# %%
snakemake@input
# Out:
# [[1]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/config.yaml"
#
# [[2]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet"
#
# [[3]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet.done"
#
# [[4]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet"
#
# [[5]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet.done"
#
# $featureset_config
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/config.yaml"
#
# $data_pq
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet"
#
# $data_pq_done
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/fset@watershed/data.parquet.done"
#
# $subset_pq
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet"
#
# $subset_pq_done
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/subset/dna_only.parquet.done"

# %%
snakemake@output
# Out:
# [[1]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/train.parquet"
#
# [[2]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/test.parquet"
#
# [[3]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/model.joblib"
#
# [[4]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/features.yaml"
#
# [[5]]
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/done"
#
# $train_data_dir
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/train.parquet"
#
# $test_data_dir
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/test.parquet"
#
# $model_joblib
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/model.joblib"
#
# $features_yaml
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/features.yaml"
#
# $touch_file
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/done"

# %%
featureset_config = read_yaml(snakemake@input$featureset_config)
featureset_config
# Out:
# $features
# $features$vep
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/feature_sets/aggregate_vep_spark.py@gt=any_tl=CANONICAL"
#
#
# $pivot_tissues
# [1] TRUE
#
# $snakemake
# $snakemake$input
# $snakemake$input$features
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/feature_sets/aggregate_vep_spark.py@gt=any_tl=CANONICAL/data.parquet.done"
#
#
#
# $variables
# $variables$vep
# $variables$vep[[1]]
# $variables$vep[[1]]$features
#  [1] "cadd_raw.max"
#  [2] "LoF_HC.max"
#  [3] "LoF_LC.max"
#  [4] "5_prime_UTR_variant.max"
#  [5] "3_prime_UTR_variant.max"
#  [6] "TF_binding_site_variant.max"
#  [7] "downstream_gene_variant.max"
#  [8] "intergenic_variant.max"
#  [9] "intron_variant.max"
# [10] "missense_variant.max"
# [11] "non_coding_transcript_exon_variant.max"
# [12] "regulatory_region_variant.max"
# [13] "splice_acceptor_variant.max"
# [14] "splice_donor_variant.max"
# [15] "splice_region_variant.max"
# [16] "stop_gained.max"
# [17] "synonymous_variant.max"
# [18] "upstream_gene_variant.max"
# [19] "sift_score.pval_max_significant"
# [20] "polyphen_score.max"

# %%
data_dt = (
    open_dataset(snakemake@input$subset_pq)
    %>% select(`individual`, `gene`)
    %>% unique()
    %>% collect()
    %>% left_join(
        open_dataset(snakemake@input$data_pq) %>% collect(),
        by=c("individual", "gene")
    )
    # %>% select(`subtissue`, `tissue`, `hilo_padj`)
    # %>% rename(tissue_type=tissue, tissue=subtissue)
    %>% as.data.table()
)
data_dt
# Out:
#         individual gene            zscore.Adipose.20..20Subcutaneous
# 1       GTEX-111FC ENSG00000242485  1.85411739
# 2       GTEX-111FC ENSG00000242498 -0.37956986
# 3       GTEX-111FC ENSG00000242612 -0.05015500
# 4       GTEX-111FC ENSG00000242616 -2.10302806
# 5       GTEX-111FC ENSG00000242732  0.53561491
# 6       GTEX-111FC ENSG00000242802  0.18442126
# 7       GTEX-111FC ENSG00000242866          NA
# 8       GTEX-111FC ENSG00000243147 -0.37287977
# 9       GTEX-111FC ENSG00000243156  0.80936199
# 10      GTEX-111FC ENSG00000243207 -0.12603074
# 11      GTEX-111FC ENSG00000243232          NA
# 12      GTEX-111FC ENSG00000243244 -1.04666114
# 13      GTEX-111FC ENSG00000243279 -0.57651907
# 14      GTEX-111FC ENSG00000243317 -2.11746550
# 15      GTEX-111FC ENSG00000243335  2.06477213
# 16      GTEX-111FC ENSG00000243477  0.31702247
# 17      GTEX-111FC ENSG00000243509          NA
# 18      GTEX-111FC ENSG00000243678  0.84330946
# 19      GTEX-111FC ENSG00000243708 -0.86075097
# 20      GTEX-111FC ENSG00000243716  1.62548923
# 21      GTEX-111FC ENSG00000243789 -1.17174566
# 22      GTEX-111FC ENSG00000243943 -0.52443832
# 23      GTEX-111FC ENSG00000243989 -0.76403993
# 24      GTEX-111FC ENSG00000244005  1.12326407
# 25      GTEX-111FC ENSG00000244038  0.01910071
# 26      GTEX-111FC ENSG00000244045  0.30339578
# 27      GTEX-111FC ENSG00000244165          NA
# 28      GTEX-111FC ENSG00000244187  0.78475946
# 29      GTEX-111FC ENSG00000244242          NA
# 30      GTEX-111FC ENSG00000244274 -0.34921643
# ⋮       ⋮          ⋮               ⋮
# 9203073 GTEX-12WSM ENSG00000197467 NA
# 9203074 GTEX-12WSM ENSG00000197991 NA
# 9203075 GTEX-12WSM ENSG00000204899 NA
# 9203076 GTEX-12WSM ENSG00000219073 NA
# 9203077 GTEX-12WSM ENSG00000268434 NA
# 9203078 GTEX-12WSM ENSG00000280165 NA
# 9203079 GTEX-12WSM ENSG00000002746 NA
# 9203080 GTEX-12WSM ENSG00000006116 NA
# 9203081 GTEX-12WSM ENSG00000006128 NA
# 9203082 GTEX-12WSM ENSG00000006283 NA
# 9203083 GTEX-12WSM ENSG00000007372 NA
# 9203084 GTEX-12WSM ENSG00000008118 NA
# 9203085 GTEX-12WSM ENSG00000011083 NA
# 9203086 GTEX-12WSM ENSG00000011332 NA
# 9203087 GTEX-12WSM ENSG00000011677 NA
# 9203088 GTEX-12WSM ENSG00000015592 NA
# 9203089 GTEX-12WSM ENSG00000022355 NA
# 9203090 GTEX-12WSM ENSG00000040608 NA
# 9203091 GTEX-12WSM ENSG00000040731 NA
# 9203092 GTEX-12WSM ENSG00000053108 NA
# 9203093 GTEX-12WSM ENSG00000058335 NA
# 9203094 GTEX-12WSM ENSG00000063015 NA
# 9203095 GTEX-12WSM ENSG00000067715 NA
# 9203096 GTEX-12WSM ENSG00000067842 NA
# 9203097 GTEX-12WSM ENSG00000074317 NA
# 9203098 GTEX-12WSM ENSG00000074706 NA
# 9203099 GTEX-12WSM ENSG00000075035 NA
# 9203100 GTEX-12WSM ENSG00000075340 NA
# 9203101 GTEX-12WSM ENSG00000075461 NA
# 9203102 GTEX-12WSM ENSG00000077080 NA
#         zscore.Adipose.20..20Visceral.20.28Omentum.29 zscore.Adrenal.20Gland
# 1       NA                                            NA
# 2       NA                                            NA
# 3       NA                                            NA
# 4       NA                                            NA
# 5       NA                                            NA
# 6       NA                                            NA
# 7       NA                                            NA
# 8       NA                                            NA
# 9       NA                                            NA
# 10      NA                                            NA
# 11      NA                                            NA
# 12      NA                                            NA
# 13      NA                                            NA
# 14      NA                                            NA
# 15      NA                                            NA
# 16      NA                                            NA
# 17      NA                                            NA
# 18      NA                                            NA
# 19      NA                                            NA
# 20      NA                                            NA
# 21      NA                                            NA
# 22      NA                                            NA
# 23      NA                                            NA
# 24      NA                                            NA
# 25      NA                                            NA
# 26      NA                                            NA
# 27      NA                                            NA
# 28      NA                                            NA
# 29      NA                                            NA
# 30      NA                                            NA
# ⋮       ⋮                                             ⋮
# 9203073 NA                                            NA
# 9203074 NA                                            NA
# 9203075 NA                                            NA
# 9203076 NA                                            NA
# 9203077 NA                                            NA
# 9203078 NA                                            NA
# 9203079 NA                                            NA
# 9203080 NA                                            NA
# 9203081 NA                                            NA
# 9203082 NA                                            NA
# 9203083 NA                                            NA
# 9203084 NA                                            NA
# 9203085 NA                                            NA
# 9203086 NA                                            NA
# 9203087 NA                                            NA
# 9203088 NA                                            NA
# 9203089 NA                                            NA
# 9203090 NA                                            NA
# 9203091 NA                                            NA
# 9203092 NA                                            NA
# 9203093 NA                                            NA
# 9203094 NA                                            NA
# 9203095 NA                                            NA
# 9203096 NA                                            NA
# 9203097 NA                                            NA
# 9203098 NA                                            NA
# 9203099 NA                                            NA
# 9203100 NA                                            NA
# 9203101 NA                                            NA
# 9203102 NA                                            NA
#         zscore.Artery.20..20Aorta zscore.Artery.20..20Coronary
# 1       NA                        NA
# 2       NA                        NA
# 3       NA                        NA
# 4       NA                        NA
# 5       NA                        NA
# 6       NA                        NA
# 7       NA                        NA
# 8       NA                        NA
# 9       NA                        NA
# 10      NA                        NA
# 11      NA                        NA
# 12      NA                        NA
# 13      NA                        NA
# 14      NA                        NA
# 15      NA                        NA
# 16      NA                        NA
# 17      NA                        NA
# 18      NA                        NA
# 19      NA                        NA
# 20      NA                        NA
# 21      NA                        NA
# 22      NA                        NA
# 23      NA                        NA
# 24      NA                        NA
# 25      NA                        NA
# 26      NA                        NA
# 27      NA                        NA
# 28      NA                        NA
# 29      NA                        NA
# 30      NA                        NA
# ⋮       ⋮                         ⋮
# 9203073 NA                        NA
# 9203074 NA                        NA
# 9203075 NA                        NA
# 9203076 NA                        NA
# 9203077 NA                        NA
# 9203078 NA                        NA
# 9203079 NA                        NA
# 9203080 NA                        NA
# 9203081 NA                        NA
# 9203082 NA                        NA
# 9203083 NA                        NA
# 9203084 NA                        NA
# 9203085 NA                        NA
# 9203086 NA                        NA
# 9203087 NA                        NA
# 9203088 NA                        NA
# 9203089 NA                        NA
# 9203090 NA                        NA
# 9203091 NA                        NA
# 9203092 NA                        NA
# 9203093 NA                        NA
# 9203094 NA                        NA
# 9203095 NA                        NA
# 9203096 NA                        NA
# 9203097 NA                        NA
# 9203098 NA                        NA
# 9203099 NA                        NA
# 9203100 NA                        NA
# 9203101 NA                        NA
# 9203102 NA                        NA
#         zscore.Artery.20..20Tibial zscore.Brain.20..20Amygdala
# 1        4.2041435                 NA
# 2       -1.4469603                 NA
# 3               NA                 NA
# 4       -0.5293633                 NA
# 5        0.7791980                 NA
# 6        1.3151004                 NA
# 7               NA                 NA
# 8        0.4247104                 NA
# 9       -1.1502731                 NA
# 10              NA                 NA
# 11              NA                 NA
# 12      -0.4220687                 NA
# 13      -0.7065473                 NA
# 14      -2.8373682                 NA
# 15       0.4775923                 NA
# 16              NA                 NA
# 17              NA                 NA
# 18      -0.9445905                 NA
# 19      -0.5047761                 NA
# 20       0.9188598                 NA
# 21              NA                 NA
# 22      -0.4041744                 NA
# 23              NA                 NA
# 24      -0.5554532                 NA
# 25      -1.6833209                 NA
# 26       0.6758662                 NA
# 27              NA                 NA
# 28              NA                 NA
# 29      -1.2081398                 NA
# 30      -0.3527340                 NA
# ⋮       ⋮                          ⋮
# 9203073  0.09704535                NA
# 9203074  0.08193045                NA
# 9203075 -1.14261353                NA
# 9203076  0.18704577                NA
# 9203077  0.04973855                NA
# 9203078  0.03029470                NA
# 9203079          NA                NA
# 9203080          NA                NA
# 9203081          NA                NA
# 9203082          NA                NA
# 9203083          NA                NA
# 9203084          NA                NA
# 9203085          NA                NA
# 9203086          NA                NA
# 9203087          NA                NA
# 9203088          NA                NA
# 9203089          NA                NA
# 9203090          NA                NA
# 9203091          NA                NA
# 9203092          NA                NA
# 9203093          NA                NA
# 9203094          NA                NA
# 9203095          NA                NA
# 9203096          NA                NA
# 9203097          NA                NA
# 9203098          NA                NA
# 9203099          NA                NA
# 9203100          NA                NA
# 9203101          NA                NA
# 9203102          NA                NA
#         zscore.Brain.20..20Anterior.20cingulate.20cortex.20.28BA24.29 ⋯
# 1       NA                                                            ⋯
# 2       NA                                                            ⋯
# 3       NA                                                            ⋯
# 4       NA                                                            ⋯
# 5       NA                                                            ⋯
# 6       NA                                                            ⋯
# 7       NA                                                            ⋯
# 8       NA                                                            ⋯
# 9       NA                                                            ⋯
# 10      NA                                                            ⋯
# 11      NA                                                            ⋯
# 12      NA                                                            ⋯
# 13      NA                                                            ⋯
# 14      NA                                                            ⋯
# 15      NA                                                            ⋯
# 16      NA                                                            ⋯
# 17      NA                                                            ⋯
# 18      NA                                                            ⋯
# 19      NA                                                            ⋯
# 20      NA                                                            ⋯
# 21      NA                                                            ⋯
# 22      NA                                                            ⋯
# 23      NA                                                            ⋯
# 24      NA                                                            ⋯
# 25      NA                                                            ⋯
# 26      NA                                                            ⋯
# 27      NA                                                            ⋯
# 28      NA                                                            ⋯
# 29      NA                                                            ⋯
# 30      NA                                                            ⋯
# ⋮       ⋮                                                             ⋱
# 9203073          NA                                                   ⋯
# 9203074          NA                                                   ⋯
# 9203075  0.31839240                                                   ⋯
# 9203076          NA                                                   ⋯
# 9203077          NA                                                   ⋯
# 9203078          NA                                                   ⋯
# 9203079 -1.01289392                                                   ⋯
# 9203080 -1.54706705                                                   ⋯
# 9203081  1.07166135                                                   ⋯
# 9203082  1.15556836                                                   ⋯
# 9203083 -0.70208222                                                   ⋯
# 9203084  1.56174541                                                   ⋯
# 9203085 -0.29825583                                                   ⋯
# 9203086 -0.31919223                                                   ⋯
# 9203087  1.91144168                                                   ⋯
# 9203088  0.83833265                                                   ⋯
# 9203089  0.23615451                                                   ⋯
# 9203090 -0.95334876                                                   ⋯
# 9203091  0.42996737                                                   ⋯
# 9203092 -1.10123491                                                   ⋯
# 9203093  0.17803499                                                   ⋯
# 9203094 -0.32234958                                                   ⋯
# 9203095  0.09506775                                                   ⋯
# 9203096 -1.01087904                                                   ⋯
# 9203097 -0.69375616                                                   ⋯
# 9203098  0.23834351                                                   ⋯
# 9203099  0.41204196                                                   ⋯
# 9203100  0.13030526                                                   ⋯
# 9203101  0.51624906                                                   ⋯
# 9203102 -0.03901900                                                   ⋯
#         feature.vep.features.regulatory_region_variant.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073 FALSE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102 FALSE
#         feature.vep.features.splice_acceptor_variant.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073 FALSE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102 FALSE
#         feature.vep.features.splice_donor_variant.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073 FALSE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102 FALSE
#         feature.vep.features.splice_region_variant.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073 FALSE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102 FALSE
#         feature.vep.features.stop_gained.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073 FALSE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102 FALSE
#         feature.vep.features.synonymous_variant.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073 FALSE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102 FALSE
#         feature.vep.features.upstream_gene_variant.max
# 1       FALSE
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11      FALSE
# 12      FALSE
# 13         NA
# 14      FALSE
# 15         NA
# 16         NA
# 17      FALSE
# 18         NA
# 19         NA
# 20      FALSE
# 21         NA
# 22      FALSE
# 23         NA
# 24      FALSE
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮       ⋮
# 9203073  TRUE
# 9203074    NA
# 9203075    NA
# 9203076    NA
# 9203077    NA
# 9203078    NA
# 9203079 FALSE
# 9203080 FALSE
# 9203081    NA
# 9203082 FALSE
# 9203083    NA
# 9203084    NA
# 9203085 FALSE
# 9203086    NA
# 9203087 FALSE
# 9203088    NA
# 9203089 FALSE
# 9203090    NA
# 9203091 FALSE
# 9203092 FALSE
# 9203093 FALSE
# 9203094 FALSE
# 9203095 FALSE
# 9203096    NA
# 9203097    NA
# 9203098    NA
# 9203099    NA
# 9203100    NA
# 9203101 FALSE
# 9203102  TRUE
#         feature.vep.features.sift_score.pval_max_significant
# 1       NA
# 2       NA
# 3       NA
# 4       NA
# 5       NA
# 6       NA
# 7       NA
# 8       NA
# 9       NA
# 10      NA
# 11      NA
# 12      NA
# 13      NA
# 14      NA
# 15      NA
# 16      NA
# 17      NA
# 18      NA
# 19      NA
# 20      NA
# 21      NA
# 22      NA
# 23      NA
# 24      NA
# 25      NA
# 26      NA
# 27      NA
# 28      NA
# 29      NA
# 30      NA
# ⋮       ⋮
# 9203073 NA
# 9203074 NA
# 9203075 NA
# 9203076 NA
# 9203077 NA
# 9203078 NA
# 9203079 NA
# 9203080 NA
# 9203081 NA
# 9203082 NA
# 9203083 NA
# 9203084 NA
# 9203085 NA
# 9203086 NA
# 9203087 NA
# 9203088 NA
# 9203089 NA
# 9203090 NA
# 9203091 NA
# 9203092 NA
# 9203093 NA
# 9203094 NA
# 9203095 NA
# 9203096 NA
# 9203097 NA
# 9203098 NA
# 9203099 NA
# 9203100 NA
# 9203101 NA
# 9203102 NA
#         feature.vep.features.polyphen_score.max fold
# 1       NA                                      3
# 2       NA                                      3
# 3       NA                                      3
# 4       NA                                      3
# 5       NA                                      3
# 6       NA                                      3
# 7       NA                                      3
# 8       NA                                      3
# 9       NA                                      3
# 10      NA                                      3
# 11      NA                                      3
# 12      NA                                      3
# 13      NA                                      3
# 14      NA                                      3
# 15      NA                                      3
# 16      NA                                      3
# 17      NA                                      3
# 18      NA                                      3
# 19      NA                                      3
# 20      NA                                      3
# 21      NA                                      3
# 22      NA                                      3
# 23      NA                                      3
# 24      NA                                      3
# 25      NA                                      3
# 26      NA                                      3
# 27      NA                                      3
# 28      NA                                      3
# 29      NA                                      3
# 30      NA                                      3
# ⋮       ⋮                                       ⋮
# 9203073 NA                                      4
# 9203074 NA                                      4
# 9203075 NA                                      4
# 9203076 NA                                      4
# 9203077 NA                                      4
# 9203078 NA                                      4
# 9203079 NA                                      4
# 9203080 NA                                      4
# 9203081 NA                                      4
# 9203082 NA                                      4
# 9203083 NA                                      4
# 9203084 NA                                      4
# 9203085 NA                                      4
# 9203086 NA                                      4
# 9203087 NA                                      4
# 9203088 NA                                      4
# 9203089 NA                                      4
# 9203090 NA                                      4
# 9203091 NA                                      4
# 9203092 NA                                      4
# 9203093 NA                                      4
# 9203094 NA                                      4
# 9203095 NA                                      4
# 9203096 NA                                      4
# 9203097 NA                                      4
# 9203098 NA                                      4
# 9203099 NA                                      4
# 9203100 NA                                      4
# 9203101 NA                                      4
# 9203102 NA                                      4

# %%
# remove infinite values
data_dt$`feature.vep.features.sift_score.pval_max_significant`[is.infinite(data_dt$`feature.vep.features.sift_score.pval_max_significant`)] = 200

# %%
data_dt[, unique(`feature.vep.features.TF_binding_site_variant.max`)]
# Out:
# [1] FALSE    NA

# %%
data_dt[, unique(`feature.vep.features.regulatory_region_variant.max`)]
# Out:
# [1] FALSE    NA

# %%
data_dt[, unique(`feature.vep.features.intergenic_variant.max`)]
# Out:
# [1] FALSE    NA

# %%
data_dt = data_dt[, !c(
    "feature.vep.features.TF_binding_site_variant.max",
    "feature.vep.features.regulatory_region_variant.max",
    "feature.vep.features.intergenic_variant.max"
)]

# %%
# Load in and parse Watershed input file
load_watershed_data <- function(data_dt, use_adjusted_pvalues=FALSE, pvalue_threshold=0.05, num_dims=NULL, num_features=NULL) {
    target_dt = data_dt %>% select(all_of(colnames(data_dt)[startsWith(colnames(data_dt), "y_truecat")]))
    pval_dt = data_dt %>% select(all_of(colnames(data_dt)[startsWith(colnames(data_dt), "pval")]))
    padj_dt = data_dt %>% select(all_of(colnames(data_dt)[startsWith(colnames(data_dt), "padj")]))
    feat_dt = data_dt %>% select(all_of(colnames(data_dt)[startsWith(colnames(data_dt), "feature")]))
    
    if (is.null(num_dims)) {
        number_of_dimensions = length(colnames(pval_dt))
    } else{
        number_of_dimensions = num_dims
        target_dt = target_dt[, 1:num_dims]
        pval_dt = pval_dt[, 1:num_dims]
        padj_dt = padj_dt[, 1:num_dims]
    }
    if (! is.null(num_features)) {
        feat_dt = feat_dt[, 1:num_features]
    }

    rownames = data_dt[,paste(`individual`, ":", `gene`, sep="")]

    feat = as.matrix(feat_dt)
    feat[is.na(feat)] = 0
    feat[is.nan(feat)] = 0
    rownames(feat) <- rownames

    if (use_adjusted_pvalues) {
        print("Using adjusted p-values...")
        # use adjusted p-values
        outlier_pvalues = as.matrix(padj_dt)
    } else {
        # use nominal p-values
        print("Using nominal p-values...")
        outlier_pvalues = as.matrix(pval_dt)
    }
    rownames(outlier_pvalues) <- rownames

    outliers_binary <- ifelse(abs(outlier_pvalues) <= pvalue_threshold, 1, 0)
    # Convert outlier status into discretized random variables
    outliers_discrete <- get_discretized_outliers(outlier_pvalues)
    # Put all data into compact data structure
    data_input <- list(
        feat=as.matrix(feat),
        outliers_binary=as.matrix(outliers_binary),
        outliers_discrete=outliers_discrete,
        number_of_dimensions=number_of_dimensions
    )
    return(data_input)
}

# %%
predict_watershed = function(watershed_object, prediction_data_input) {
    # Parse data_input for relevent data
    predictions_feat <- prediction_data_input$feat
    predictions_discretized_outliers <- prediction_data_input$outliers_discrete
    # Scale prediction features (according to mean and standard deviation from training data)
    predictions_feat <- scale(predictions_feat, center=watershed_object$mean_feat, scale=watershed_object$sd_feat)
    number_dimensions <- prediction_data_input$number_of_dimensions


    ########################
    ## Inference to compute Watershed posterior probabilities
    ########################
    # watershed_info <- update_marginal_posterior_probabilities(predictions_feat, predictions_discretized_outliers, watershed_object$model_params)
    # watershed_posteriors <- watershed_info$probability  # Marginal posteriors

    # We do not need Expression for inference, therefore replace `predictions_discretized_outliers` with an empty `matrix()`.
    watershed_z_given_g = update_conditional_z_given_g_probabilities(predictions_feat, matrix(), watershed_object$model_params)
    watershed_z_given_g_posteriors = watershed_z_given_g$probability
    colnames(watershed_z_given_g_posteriors) = watershed_object$pred_names

    # ########################
    # # Add row names and column names to posterior predictions matrix
    # ########################
    # watershed_z_given_g_posteriors_mat <- cbind(rownames(predictions_feat), watershed_z_given_g_posteriors)
    # colnames(watershed_z_given_g_posteriors_mat) = c("sample_names", paste0("watershed_z_given_g_posterior_outlier_signal_", 1:number_dimensions))
    
    return(watershed_z_given_g_posteriors)
}

# %%
row_any <- function(dt, cols) {
  return(dt[, Reduce(`|`, .SD), .SDcols=cols])
}

# %%
row_all_na <- function(dt, cols) {
  return(dt[, Reduce(`&`, lapply(.SD, is.na)), .SDcols=cols])
}

# %%
folds = data_dt[["fold"]] %>% unique()
folds
# Out:
# [1] "3"    "4"    "1"    "0"    "2"    "test"

# %%
fold_dirs = paste(snakemake@params$output_basedir, "fold", folds, sep="/")
fold_dirs
# Out:
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/fold/3"
# [2] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/fold/4"
# [3] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/fold/1"
# [4] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/fold/0"
# [5] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/fold/2"
# [6] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/fold/test"

# %%
predict_fold = function(target_fold) {
    pvalue_threshold = 0.2
    fold_dir = paste(snakemake@params$output_basedir, "fold", target_fold, sep="/")
    
    print(paste0("Reading fold ", target_fold, "..."))

    testing_data = data_dt %>% filter(`fold` == .env$target_fold)
    testing_watershed_data = load_watershed_data(
        testing_data,
        use_adjusted_pvalues=FALSE,
        pvalue_threshold=pvalue_threshold
    )

    #######################################
    ## Train Watershed model on training data
    #######################################
    print("Loading watershed object...")
    watershed_object <- readRDS(paste(fold_dir, "model.rds", sep="/"))

    print("Predicting watershed scores...")
    test_predictions = cbind(
        testing_data %>% select(`individual`, `gene`),
        as.data.table(predict_watershed(watershed_object, testing_watershed_data))
    ) %>% mutate(fold = target_fold)
    # test_predictions
    
    return(test_predictions)
}

# %%
predictions_dt = rbindlist(lapply(folds, predict_fold))
predictions_dt

# %%
write_dataset(predictions_dt, paste0(snakemake@params$output_basedir, "/validation_predictions.parquet"), partitioning="fold")

# %% [raw]
# predictions_dt = (
#     open_dataset(paste0(snakemake@params$output_basedir, "/validation_predictions.parquet"))
#     %>% collect()
#     %>% as.data.table()
# )
# predictions_dt

# %%
colnames(predictions_dt)
# Out:
#  [1] "individual"
#  [2] "gene"
#  [3] "pval.Adipose.20..20Subcutaneous"
#  [4] "pval.Adipose.20..20Visceral.20.28Omentum.29"
#  [5] "pval.Adrenal.20Gland"
#  [6] "pval.Artery.20..20Aorta"
#  [7] "pval.Artery.20..20Coronary"
#  [8] "pval.Artery.20..20Tibial"
#  [9] "pval.Brain.20..20Amygdala"
# [10] "pval.Brain.20..20Anterior.20cingulate.20cortex.20.28BA24.29"
# [11] "pval.Brain.20..20Caudate.20.28basal.20ganglia.29"
# [12] "pval.Brain.20..20Cerebellar.20Hemisphere"
# [13] "pval.Brain.20..20Cerebellum"
# [14] "pval.Brain.20..20Cortex"
# [15] "pval.Brain.20..20Frontal.20Cortex.20.28BA9.29"
# [16] "pval.Brain.20..20Hippocampus"
# [17] "pval.Brain.20..20Hypothalamus"
# [18] "pval.Brain.20..20Nucleus.20accumbens.20.28basal.20ganglia.29"
# [19] "pval.Brain.20..20Putamen.20.28basal.20ganglia.29"
# [20] "pval.Brain.20..20Spinal.20cord.20.28cervical.20c.1.29"
# [21] "pval.Brain.20..20Substantia.20nigra"
# [22] "pval.Breast.20..20Mammary.20Tissue"
# [23] "pval.Cells.20..20Cultured.20fibroblasts"
# [24] "pval.Cells.20..20EBV.transformed.20lymphocytes"
# [25] "pval.Colon.20..20Sigmoid"
# [26] "pval.Colon.20..20Transverse"
# [27] "pval.Esophagus.20..20Gastroesophageal.20Junction"
# [28] "pval.Esophagus.20..20Mucosa"
# [29] "pval.Esophagus.20..20Muscularis"
# [30] "pval.Heart.20..20Atrial.20Appendage"
# [31] "pval.Heart.20..20Left.20Ventricle"
# [32] "pval.Liver"
# [33] "pval.Lung"
# [34] "pval.Minor.20Salivary.20Gland"
# [35] "pval.Muscle.20..20Skeletal"
# [36] "pval.Nerve.20..20Tibial"
# [37] "pval.Ovary"
# [38] "pval.Pancreas"
# [39] "pval.Pituitary"
# [40] "pval.Prostate"
# [41] "pval.Skin.20..20Not.20Sun.20Exposed.20.28Suprapubic.29"
# [42] "pval.Skin.20..20Sun.20Exposed.20.28Lower.20leg.29"
# [43] "pval.Small.20Intestine.20..20Terminal.20Ileum"
# [44] "pval.Spleen"
# [45] "pval.Stomach"
# [46] "pval.Testis"
# [47] "pval.Thyroid"
# [48] "pval.Uterus"
# [49] "pval.Vagina"
# [50] "pval.Whole.20Blood"
# [51] "fold"

# %%
column_mapping <- c(
    "pval.Adipose.20..20Subcutaneous" = "Adipose - Subcutaneous",
    "pval.Adipose.20..20Visceral.20.28Omentum.29" = "Adipose - Visceral (Omentum)",
    "pval.Adrenal.20Gland" = "Adrenal Gland",
    "pval.Artery.20..20Aorta" = "Artery - Aorta",
    "pval.Artery.20..20Coronary" = "Artery - Coronary",
    "pval.Artery.20..20Tibial" = "Artery - Tibial",
    "pval.Brain.20..20Amygdala" = "Brain - Amygdala",
    "pval.Brain.20..20Anterior.20cingulate.20cortex.20.28BA24.29" = "Brain - Anterior cingulate cortex (BA24)",
    "pval.Brain.20..20Caudate.20.28basal.20ganglia.29" = "Brain - Caudate (basal ganglia)",
    "pval.Brain.20..20Cerebellar.20Hemisphere" = "Brain - Cerebellar Hemisphere",
    "pval.Brain.20..20Cerebellum" = "Brain - Cerebellum",
    "pval.Brain.20..20Cortex" = "Brain - Cortex",
    "pval.Brain.20..20Frontal.20Cortex.20.28BA9.29" = "Brain - Frontal Cortex (BA9)",
    "pval.Brain.20..20Hippocampus" = "Brain - Hippocampus",
    "pval.Brain.20..20Hypothalamus" = "Brain - Hypothalamus",
    "pval.Brain.20..20Nucleus.20accumbens.20.28basal.20ganglia.29" = "Brain - Nucleus accumbens (basal ganglia)",
    "pval.Brain.20..20Putamen.20.28basal.20ganglia.29" = "Brain - Putamen (basal ganglia)",
    "pval.Brain.20..20Spinal.20cord.20.28cervical.20c.1.29" = "Brain - Spinal cord (cervical c-1)",
    "pval.Brain.20..20Substantia.20nigra" = "Brain - Substantia nigra",
    "pval.Breast.20..20Mammary.20Tissue" = "Breast - Mammary Tissue",
    "pval.Cells.20..20Cultured.20fibroblasts" = "Cells - Cultured fibroblasts",
    "pval.Cells.20..20EBV.transformed.20lymphocytes" = "Cells - EBV-transformed lymphocytes",
    "pval.Colon.20..20Sigmoid" = "Colon - Sigmoid",
    "pval.Colon.20..20Transverse" = "Colon - Transverse",
    "pval.Esophagus.20..20Gastroesophageal.20Junction" = "Esophagus - Gastroesophageal Junction",
    "pval.Esophagus.20..20Mucosa" = "Esophagus - Mucosa",
    "pval.Esophagus.20..20Muscularis" = "Esophagus - Muscularis",
    "pval.Heart.20..20Atrial.20Appendage" = "Heart - Atrial Appendage",
    "pval.Heart.20..20Left.20Ventricle" = "Heart - Left Ventricle",
    "pval.Liver" = "Liver",
    "pval.Lung" = "Lung",
    "pval.Minor.20Salivary.20Gland" = "Minor Salivary Gland",
    "pval.Muscle.20..20Skeletal" = "Muscle - Skeletal",
    "pval.Nerve.20..20Tibial" = "Nerve - Tibial",
    "pval.Ovary" = "Ovary",
    "pval.Pancreas" = "Pancreas",
    "pval.Pituitary" = "Pituitary",
    "pval.Prostate" = "Prostate",
    "pval.Skin.20..20Not.20Sun.20Exposed.20.28Suprapubic.29" = "Skin - Not Sun Exposed (Suprapubic)",
    "pval.Skin.20..20Sun.20Exposed.20.28Lower.20leg.29" = "Skin - Sun Exposed (Lower leg)",
    "pval.Small.20Intestine.20..20Terminal.20Ileum" = "Small Intestine - Terminal Ileum",
    "pval.Spleen" = "Spleen",
    "pval.Stomach" = "Stomach",
    "pval.Testis" = "Testis",
    "pval.Thyroid" = "Thyroid",
    "pval.Uterus" = "Uterus",
    "pval.Vagina" = "Vagina",
    "pval.Whole.20Blood" = "Whole Blood"
)

# %%
melted_predictions_dt <- melt(
    predictions_dt,
    id.vars = c("individual", "gene", "fold"),
    variable.name = "subtissue",
    value.name = "y_pred"
)
# Rename the 'subtissue' column using the mapping defined above
melted_predictions_dt$subtissue <- column_mapping[melted_predictions_dt$subtissue]
# convert p-values to -log10(p)
melted_predictions_dt$y_pred_proba <- -log10(melted_predictions_dt$y_pred)
melted_predictions_dt
# Out:
#           individual gene            fold subtissue              y_pred
# 1         GTEX-1122O ENSG00000143373 0    Adipose - Subcutaneous 0.07797306
# 2         GTEX-1122O ENSG00000143374 0    Adipose - Subcutaneous 0.07797306
# 3         GTEX-1122O ENSG00000143376 0    Adipose - Subcutaneous 0.07955494
# 4         GTEX-1122O ENSG00000143379 0    Adipose - Subcutaneous 0.07797306
# 5         GTEX-1122O ENSG00000143382 0    Adipose - Subcutaneous 0.07797306
# 6         GTEX-1122O ENSG00000143384 0    Adipose - Subcutaneous 0.07797306
# 7         GTEX-1122O ENSG00000143387 0    Adipose - Subcutaneous 0.07797306
# 8         GTEX-1122O ENSG00000143390 0    Adipose - Subcutaneous 0.07797306
# 9         GTEX-1122O ENSG00000143393 0    Adipose - Subcutaneous 0.07797306
# 10        GTEX-1122O ENSG00000143398 0    Adipose - Subcutaneous 0.07797306
# 11        GTEX-1122O ENSG00000143401 0    Adipose - Subcutaneous 0.07797306
# 12        GTEX-1122O ENSG00000143409 0    Adipose - Subcutaneous 0.07797306
# 13        GTEX-1122O ENSG00000143416 0    Adipose - Subcutaneous 0.07797306
# 14        GTEX-1122O ENSG00000143418 0    Adipose - Subcutaneous 0.07797306
# 15        GTEX-1122O ENSG00000143420 0    Adipose - Subcutaneous 0.07797306
# 16        GTEX-1122O ENSG00000143434 0    Adipose - Subcutaneous 0.07888850
# 17        GTEX-1122O ENSG00000143436 0    Adipose - Subcutaneous 0.07797306
# 18        GTEX-1122O ENSG00000143437 0    Adipose - Subcutaneous 0.07797306
# 19        GTEX-1122O ENSG00000143442 0    Adipose - Subcutaneous 0.07797306
# 20        GTEX-1122O ENSG00000143457 0    Adipose - Subcutaneous 0.07797306
# 21        GTEX-1122O ENSG00000143458 0    Adipose - Subcutaneous 0.08215314
# 22        GTEX-1122O ENSG00000143486 0    Adipose - Subcutaneous 0.08045206
# 23        GTEX-1122O ENSG00000143514 0    Adipose - Subcutaneous 0.07797306
# 24        GTEX-1122O ENSG00000143515 0    Adipose - Subcutaneous 0.07797306
# 25        GTEX-1122O ENSG00000143537 0    Adipose - Subcutaneous 0.07797306
# 26        GTEX-1122O ENSG00000143543 0    Adipose - Subcutaneous 0.07797306
# 27        GTEX-1122O ENSG00000143545 0    Adipose - Subcutaneous 0.07797306
# 28        GTEX-1122O ENSG00000143549 0    Adipose - Subcutaneous 0.07797306
# 29        GTEX-1122O ENSG00000143553 0    Adipose - Subcutaneous 0.07797306
# 30        GTEX-1122O ENSG00000143554 0    Adipose - Subcutaneous 0.07010269
# ⋮         ⋮          ⋮               ⋮    ⋮                      ⋮
# 441748867 GTEX-ZVT2  ENSG00000187116 test Whole Blood            0.10022211
# 441748868 GTEX-ZVT2  ENSG00000187775 test Whole Blood            0.10022211
# 441748869 GTEX-ZVT2  ENSG00000188305 test Whole Blood            0.10616153
# 441748870 GTEX-ZVT2  ENSG00000188897 test Whole Blood            0.10542747
# 441748871 GTEX-ZVT2  ENSG00000196358 test Whole Blood            0.10022212
# 441748872 GTEX-ZVT2  ENSG00000196511 test Whole Blood            0.09988048
# 441748873 GTEX-ZVT2  ENSG00000196565 test Whole Blood            0.10022211
# 441748874 GTEX-ZVT2  ENSG00000197208 test Whole Blood            0.10022211
# 441748875 GTEX-ZVT2  ENSG00000198019 test Whole Blood            0.10022212
# 441748876 GTEX-ZVT2  ENSG00000198216 test Whole Blood            0.09952283
# 441748877 GTEX-ZVT2  ENSG00000198915 test Whole Blood            0.10022212
# 441748878 GTEX-ZVT2  ENSG00000204482 test Whole Blood            0.10022212
# 441748879 GTEX-ZVT2  ENSG00000206047 test Whole Blood            0.10022212
# 441748880 GTEX-ZVT2  ENSG00000206177 test Whole Blood            0.10022211
# 441748881 GTEX-ZVT2  ENSG00000213934 test Whole Blood            0.10022212
# 441748882 GTEX-ZVT2  ENSG00000213937 test Whole Blood            0.10022212
# 441748883 GTEX-ZVT2  ENSG00000214212 test Whole Blood            0.10022212
# 441748884 GTEX-ZVT2  ENSG00000214688 test Whole Blood            0.10022211
# 441748885 GTEX-ZVT2  ENSG00000220008 test Whole Blood            0.10022211
# 441748886 GTEX-ZVT2  ENSG00000223609 test Whole Blood            0.10022212
# 441748887 GTEX-ZVT2  ENSG00000229314 test Whole Blood            0.10022211
# 441748888 GTEX-ZVT2  ENSG00000238243 test Whole Blood            0.10022211
# 441748889 GTEX-ZVT2  ENSG00000239839 test Whole Blood            0.10022211
# 441748890 GTEX-ZVT2  ENSG00000239998 test Whole Blood            0.10022212
# 441748891 GTEX-ZVT2  ENSG00000240247 test Whole Blood            0.10022212
# 441748892 GTEX-ZVT2  ENSG00000249240 test Whole Blood            0.10348496
# 441748893 GTEX-ZVT2  ENSG00000258102 test Whole Blood            0.10022212
# 441748894 GTEX-ZVT2  ENSG00000260861 test Whole Blood            0.10022212
# 441748895 GTEX-ZVT2  ENSG00000268500 test Whole Blood            0.10022212
# 441748896 GTEX-ZVT2  ENSG00000276289 test Whole Blood            0.10022211
#           y_pred_proba
# 1         1.108055
# 2         1.108055
# 3         1.099333
# 4         1.108055
# 5         1.108055
# 6         1.108055
# 7         1.108055
# 8         1.108055
# 9         1.108055
# 10        1.108055
# 11        1.108055
# 12        1.108055
# 13        1.108055
# 14        1.108055
# 15        1.108055
# 16        1.102986
# 17        1.108055
# 18        1.108055
# 19        1.108055
# 20        1.108055
# 21        1.085376
# 22        1.094463
# 23        1.108055
# 24        1.108055
# 25        1.108055
# 26        1.108055
# 27        1.108055
# 28        1.108055
# 29        1.108055
# 30        1.154265
# ⋮         ⋮
# 441748867 0.9990364
# 441748868 0.9990364
# 441748869 0.9740328
# 441748870 0.9770462
# 441748871 0.9990364
# 441748872 1.0005194
# 441748873 0.9990364
# 441748874 0.9990364
# 441748875 0.9990364
# 441748876 1.0020773
# 441748877 0.9990364
# 441748878 0.9990364
# 441748879 0.9990364
# 441748880 0.9990364
# 441748881 0.9990364
# 441748882 0.9990364
# 441748883 0.9990364
# 441748884 0.9990364
# 441748885 0.9990364
# 441748886 0.9990364
# 441748887 0.9990364
# 441748888 0.9990364
# 441748889 0.9990364
# 441748890 0.9990364
# 441748891 0.9990364
# 441748892 0.9851227
# 441748893 0.9990364
# 441748894 0.9990364
# 441748895 0.9990364
# 441748896 0.9990364

# %%
column_mapping_y_true <- c(
    "y_truecat.Adipose.20..20Subcutaneous" = "Adipose - Subcutaneous",
    "y_truecat.Adipose.20..20Visceral.20.28Omentum.29" = "Adipose - Visceral (Omentum)",
    "y_truecat.Adrenal.20Gland" = "Adrenal Gland",
    "y_truecat.Artery.20..20Aorta" = "Artery - Aorta",
    "y_truecat.Artery.20..20Coronary" = "Artery - Coronary",
    "y_truecat.Artery.20..20Tibial" = "Artery - Tibial",
    "y_truecat.Brain.20..20Amygdala" = "Brain - Amygdala",
    "y_truecat.Brain.20..20Anterior.20cingulate.20cortex.20.28BA24.29" = "Brain - Anterior cingulate cortex (BA24)",
    "y_truecat.Brain.20..20Caudate.20.28basal.20ganglia.29" = "Brain - Caudate (basal ganglia)",
    "y_truecat.Brain.20..20Cerebellar.20Hemisphere" = "Brain - Cerebellar Hemisphere",
    "y_truecat.Brain.20..20Cerebellum" = "Brain - Cerebellum",
    "y_truecat.Brain.20..20Cortex" = "Brain - Cortex",
    "y_truecat.Brain.20..20Frontal.20Cortex.20.28BA9.29" = "Brain - Frontal Cortex (BA9)",
    "y_truecat.Brain.20..20Hippocampus" = "Brain - Hippocampus",
    "y_truecat.Brain.20..20Hypothalamus" = "Brain - Hypothalamus",
    "y_truecat.Brain.20..20Nucleus.20accumbens.20.28basal.20ganglia.29" = "Brain - Nucleus accumbens (basal ganglia)",
    "y_truecat.Brain.20..20Putamen.20.28basal.20ganglia.29" = "Brain - Putamen (basal ganglia)",
    "y_truecat.Brain.20..20Spinal.20cord.20.28cervical.20c.1.29" = "Brain - Spinal cord (cervical c-1)",
    "y_truecat.Brain.20..20Substantia.20nigra" = "Brain - Substantia nigra",
    "y_truecat.Breast.20..20Mammary.20Tissue" = "Breast - Mammary Tissue",
    "y_truecat.Cells.20..20Cultured.20fibroblasts" = "Cells - Cultured fibroblasts",
    "y_truecat.Cells.20..20EBV.transformed.20lymphocytes" = "Cells - EBV-transformed lymphocytes",
    "y_truecat.Colon.20..20Sigmoid" = "Colon - Sigmoid",
    "y_truecat.Colon.20..20Transverse" = "Colon - Transverse",
    "y_truecat.Esophagus.20..20Gastroesophageal.20Junction" = "Esophagus - Gastroesophageal Junction",
    "y_truecat.Esophagus.20..20Mucosa" = "Esophagus - Mucosa",
    "y_truecat.Esophagus.20..20Muscularis" = "Esophagus - Muscularis",
    "y_truecat.Heart.20..20Atrial.20Appendage" = "Heart - Atrial Appendage",
    "y_truecat.Heart.20..20Left.20Ventricle" = "Heart - Left Ventricle",
    "y_truecat.Liver" = "Liver",
    "y_truecat.Lung" = "Lung",
    "y_truecat.Minor.20Salivary.20Gland" = "Minor Salivary Gland",
    "y_truecat.Muscle.20..20Skeletal" = "Muscle - Skeletal",
    "y_truecat.Nerve.20..20Tibial" = "Nerve - Tibial",
    "y_truecat.Ovary" = "Ovary",
    "y_truecat.Pancreas" = "Pancreas",
    "y_truecat.Pituitary" = "Pituitary",
    "y_truecat.Prostate" = "Prostate",
    "y_truecat.Skin.20..20Not.20Sun.20Exposed.20.28Suprapubic.29" = "Skin - Not Sun Exposed (Suprapubic)",
    "y_truecat.Skin.20..20Sun.20Exposed.20.28Lower.20leg.29" = "Skin - Sun Exposed (Lower leg)",
    "y_truecat.Small.20Intestine.20..20Terminal.20Ileum" = "Small Intestine - Terminal Ileum",
    "y_truecat.Spleen" = "Spleen",
    "y_truecat.Stomach" = "Stomach",
    "y_truecat.Testis" = "Testis",
    "y_truecat.Thyroid" = "Thyroid",
    "y_truecat.Uterus" = "Uterus",
    "y_truecat.Vagina" = "Vagina",
    "y_truecat.Whole.20Blood" = "Whole Blood"
)

# %%
y_truecat_dt = (
    data_dt %>% select(all_of(c("individual", "gene", names(column_mapping_y_true))))
    %>% melt(
        id.vars = c("individual", "gene"),
        variable.name = "subtissue",
        value.name = "y_truecat"
    )
    %>% filter(! is.na(`y_truecat`))
)
# Rename the 'subtissue' column using the mapping defined above
y_truecat_dt$subtissue <- column_mapping_y_true[y_truecat_dt$subtissue]
y_truecat_dt
# Out:
#           individual gene            subtissue              y_truecat
# 1         GTEX-111FC ENSG00000242485 Adipose - Subcutaneous FALSE
# 2         GTEX-111FC ENSG00000242498 Adipose - Subcutaneous FALSE
# 3         GTEX-111FC ENSG00000242612 Adipose - Subcutaneous FALSE
# 4         GTEX-111FC ENSG00000242616 Adipose - Subcutaneous FALSE
# 5         GTEX-111FC ENSG00000242732 Adipose - Subcutaneous FALSE
# 6         GTEX-111FC ENSG00000242802 Adipose - Subcutaneous FALSE
# 7         GTEX-111FC ENSG00000243147 Adipose - Subcutaneous FALSE
# 8         GTEX-111FC ENSG00000243156 Adipose - Subcutaneous FALSE
# 9         GTEX-111FC ENSG00000243207 Adipose - Subcutaneous FALSE
# 10        GTEX-111FC ENSG00000243244 Adipose - Subcutaneous FALSE
# 11        GTEX-111FC ENSG00000243279 Adipose - Subcutaneous FALSE
# 12        GTEX-111FC ENSG00000243317 Adipose - Subcutaneous FALSE
# 13        GTEX-111FC ENSG00000243335 Adipose - Subcutaneous FALSE
# 14        GTEX-111FC ENSG00000243477 Adipose - Subcutaneous FALSE
# 15        GTEX-111FC ENSG00000243678 Adipose - Subcutaneous FALSE
# 16        GTEX-111FC ENSG00000243708 Adipose - Subcutaneous FALSE
# 17        GTEX-111FC ENSG00000243716 Adipose - Subcutaneous FALSE
# 18        GTEX-111FC ENSG00000243789 Adipose - Subcutaneous FALSE
# 19        GTEX-111FC ENSG00000243943 Adipose - Subcutaneous FALSE
# 20        GTEX-111FC ENSG00000243989 Adipose - Subcutaneous FALSE
# 21        GTEX-111FC ENSG00000244005 Adipose - Subcutaneous FALSE
# 22        GTEX-111FC ENSG00000244038 Adipose - Subcutaneous FALSE
# 23        GTEX-111FC ENSG00000244045 Adipose - Subcutaneous FALSE
# 24        GTEX-111FC ENSG00000244187 Adipose - Subcutaneous FALSE
# 25        GTEX-111FC ENSG00000244274 Adipose - Subcutaneous FALSE
# 26        GTEX-111FC ENSG00000244405 Adipose - Subcutaneous FALSE
# 27        GTEX-111FC ENSG00000244462 Adipose - Subcutaneous FALSE
# 28        GTEX-111FC ENSG00000243725 Adipose - Subcutaneous FALSE
# 29        GTEX-111FC ENSG00000244687 Adipose - Subcutaneous FALSE
# 30        GTEX-111FC ENSG00000244731 Adipose - Subcutaneous FALSE
# ⋮         ⋮          ⋮               ⋮                      ⋮
# 100325508 GTEX-12WSL ENSG00000187037 Whole Blood            FALSE
# 100325509 GTEX-12WSL ENSG00000188305 Whole Blood            FALSE
# 100325510 GTEX-12WSL ENSG00000189068 Whole Blood            FALSE
# 100325511 GTEX-12WSL ENSG00000196358 Whole Blood            FALSE
# 100325512 GTEX-12WSL ENSG00000196565 Whole Blood            FALSE
# 100325513 GTEX-12WSL ENSG00000197208 Whole Blood            FALSE
# 100325514 GTEX-12WSL ENSG00000198019 Whole Blood            FALSE
# 100325515 GTEX-12WSL ENSG00000198336 Whole Blood            FALSE
# 100325516 GTEX-12WSL ENSG00000198821 Whole Blood            FALSE
# 100325517 GTEX-12WSL ENSG00000198915 Whole Blood            FALSE
# 100325518 GTEX-12WSL ENSG00000203618 Whole Blood            FALSE
# 100325519 GTEX-12WSL ENSG00000204397 Whole Blood            FALSE
# 100325520 GTEX-12WSL ENSG00000204420 Whole Blood            FALSE
# 100325521 GTEX-12WSL ENSG00000206047 Whole Blood            FALSE
# 100325522 GTEX-12WSL ENSG00000206177 Whole Blood            FALSE
# 100325523 GTEX-12WSL ENSG00000213934 Whole Blood            FALSE
# 100325524 GTEX-12WSL ENSG00000213937 Whole Blood            FALSE
# 100325525 GTEX-12WSL ENSG00000214212 Whole Blood            FALSE
# 100325526 GTEX-12WSL ENSG00000214688 Whole Blood            FALSE
# 100325527 GTEX-12WSL ENSG00000220008 Whole Blood            FALSE
# 100325528 GTEX-12WSL ENSG00000223609 Whole Blood            FALSE
# 100325529 GTEX-12WSL ENSG00000239839 Whole Blood            FALSE
# 100325530 GTEX-12WSL ENSG00000239998 Whole Blood            FALSE
# 100325531 GTEX-12WSL ENSG00000240247 Whole Blood            FALSE
# 100325532 GTEX-12WSL ENSG00000258102 Whole Blood            FALSE
# 100325533 GTEX-12WSL ENSG00000258227 Whole Blood            FALSE
# 100325534 GTEX-12WSL ENSG00000260861 Whole Blood            FALSE
# 100325535 GTEX-12WSL ENSG00000268500 Whole Blood            FALSE
# 100325536 GTEX-12WSL ENSG00000271605 Whole Blood            FALSE
# 100325537 GTEX-12WSL ENSG00000276289 Whole Blood            FALSE

# %%
joint_predictions_dt = (
    y_truecat_dt
    %>% left_join(melted_predictions_dt, by=c("individual", "gene", "subtissue"))
)
joint_predictions_dt
# Out:
#           individual gene            subtissue              y_truecat fold
# 1         GTEX-111FC ENSG00000242485 Adipose - Subcutaneous FALSE     3
# 2         GTEX-111FC ENSG00000242498 Adipose - Subcutaneous FALSE     3
# 3         GTEX-111FC ENSG00000242612 Adipose - Subcutaneous FALSE     3
# 4         GTEX-111FC ENSG00000242616 Adipose - Subcutaneous FALSE     3
# 5         GTEX-111FC ENSG00000242732 Adipose - Subcutaneous FALSE     3
# 6         GTEX-111FC ENSG00000242802 Adipose - Subcutaneous FALSE     3
# 7         GTEX-111FC ENSG00000243147 Adipose - Subcutaneous FALSE     3
# 8         GTEX-111FC ENSG00000243156 Adipose - Subcutaneous FALSE     3
# 9         GTEX-111FC ENSG00000243207 Adipose - Subcutaneous FALSE     3
# 10        GTEX-111FC ENSG00000243244 Adipose - Subcutaneous FALSE     3
# 11        GTEX-111FC ENSG00000243279 Adipose - Subcutaneous FALSE     3
# 12        GTEX-111FC ENSG00000243317 Adipose - Subcutaneous FALSE     3
# 13        GTEX-111FC ENSG00000243335 Adipose - Subcutaneous FALSE     3
# 14        GTEX-111FC ENSG00000243477 Adipose - Subcutaneous FALSE     3
# 15        GTEX-111FC ENSG00000243678 Adipose - Subcutaneous FALSE     3
# 16        GTEX-111FC ENSG00000243708 Adipose - Subcutaneous FALSE     3
# 17        GTEX-111FC ENSG00000243716 Adipose - Subcutaneous FALSE     3
# 18        GTEX-111FC ENSG00000243789 Adipose - Subcutaneous FALSE     3
# 19        GTEX-111FC ENSG00000243943 Adipose - Subcutaneous FALSE     3
# 20        GTEX-111FC ENSG00000243989 Adipose - Subcutaneous FALSE     3
# 21        GTEX-111FC ENSG00000244005 Adipose - Subcutaneous FALSE     3
# 22        GTEX-111FC ENSG00000244038 Adipose - Subcutaneous FALSE     3
# 23        GTEX-111FC ENSG00000244045 Adipose - Subcutaneous FALSE     3
# 24        GTEX-111FC ENSG00000244187 Adipose - Subcutaneous FALSE     3
# 25        GTEX-111FC ENSG00000244274 Adipose - Subcutaneous FALSE     3
# 26        GTEX-111FC ENSG00000244405 Adipose - Subcutaneous FALSE     3
# 27        GTEX-111FC ENSG00000244462 Adipose - Subcutaneous FALSE     3
# 28        GTEX-111FC ENSG00000243725 Adipose - Subcutaneous FALSE     3
# 29        GTEX-111FC ENSG00000244687 Adipose - Subcutaneous FALSE     3
# 30        GTEX-111FC ENSG00000244731 Adipose - Subcutaneous FALSE     3
# ⋮         ⋮          ⋮               ⋮                      ⋮         ⋮
# 100325508 GTEX-12WSL ENSG00000187037 Whole Blood            FALSE     2
# 100325509 GTEX-12WSL ENSG00000188305 Whole Blood            FALSE     2
# 100325510 GTEX-12WSL ENSG00000189068 Whole Blood            FALSE     2
# 100325511 GTEX-12WSL ENSG00000196358 Whole Blood            FALSE     2
# 100325512 GTEX-12WSL ENSG00000196565 Whole Blood            FALSE     2
# 100325513 GTEX-12WSL ENSG00000197208 Whole Blood            FALSE     2
# 100325514 GTEX-12WSL ENSG00000198019 Whole Blood            FALSE     2
# 100325515 GTEX-12WSL ENSG00000198336 Whole Blood            FALSE     2
# 100325516 GTEX-12WSL ENSG00000198821 Whole Blood            FALSE     2
# 100325517 GTEX-12WSL ENSG00000198915 Whole Blood            FALSE     2
# 100325518 GTEX-12WSL ENSG00000203618 Whole Blood            FALSE     2
# 100325519 GTEX-12WSL ENSG00000204397 Whole Blood            FALSE     2
# 100325520 GTEX-12WSL ENSG00000204420 Whole Blood            FALSE     2
# 100325521 GTEX-12WSL ENSG00000206047 Whole Blood            FALSE     2
# 100325522 GTEX-12WSL ENSG00000206177 Whole Blood            FALSE     2
# 100325523 GTEX-12WSL ENSG00000213934 Whole Blood            FALSE     2
# 100325524 GTEX-12WSL ENSG00000213937 Whole Blood            FALSE     2
# 100325525 GTEX-12WSL ENSG00000214212 Whole Blood            FALSE     2
# 100325526 GTEX-12WSL ENSG00000214688 Whole Blood            FALSE     2
# 100325527 GTEX-12WSL ENSG00000220008 Whole Blood            FALSE     2
# 100325528 GTEX-12WSL ENSG00000223609 Whole Blood            FALSE     2
# 100325529 GTEX-12WSL ENSG00000239839 Whole Blood            FALSE     2
# 100325530 GTEX-12WSL ENSG00000239998 Whole Blood            FALSE     2
# 100325531 GTEX-12WSL ENSG00000240247 Whole Blood            FALSE     2
# 100325532 GTEX-12WSL ENSG00000258102 Whole Blood            FALSE     2
# 100325533 GTEX-12WSL ENSG00000258227 Whole Blood            FALSE     2
# 100325534 GTEX-12WSL ENSG00000260861 Whole Blood            FALSE     2
# 100325535 GTEX-12WSL ENSG00000268500 Whole Blood            FALSE     2
# 100325536 GTEX-12WSL ENSG00000271605 Whole Blood            FALSE     2
# 100325537 GTEX-12WSL ENSG00000276289 Whole Blood            FALSE     2
#           y_pred     y_pred_proba
# 1         0.87882498 0.05609761
# 2         0.08119268 1.09048315
# 3         0.08119268 1.09048315
# 4         0.08119268 1.09048313
# 5         0.08119267 1.09048316
# 6         0.08119268 1.09048313
# 7         0.08119267 1.09048316
# 8         0.08119268 1.09048314
# 9         0.08119268 1.09048314
# 10        0.08466661 1.07228783
# 11        0.08119268 1.09048314
# 12        0.08641510 1.06341034
# 13        0.08119267 1.09048316
# 14        0.08119268 1.09048314
# 15        0.08119268 1.09048314
# 16        0.08119268 1.09048314
# 17        0.08441393 1.07358586
# 18        0.08119268 1.09048314
# 19        0.08439976 1.07365877
# 20        0.08119268 1.09048314
# 21        0.09100292 1.04094465
# 22        0.08119267 1.09048315
# 23        0.08119268 1.09048314
# 24        0.08119268 1.09048315
# 25        0.08119268 1.09048313
# 26        0.08491917 1.07099428
# 27        0.08275374 1.08221239
# 28        0.08572200 1.06690770
# 29        0.08119268 1.09048314
# 30        0.08119267 1.09048315
# ⋮         ⋮          ⋮
# 100325508 0.10132712 0.9942743
# 100325509 0.10132712 0.9942743
# 100325510 0.10132712 0.9942743
# 100325511 0.10132712 0.9942743
# 100325512 0.10170859 0.9926424
# 100325513 0.10136624 0.9941067
# 100325514 0.10132712 0.9942743
# 100325515 0.10132712 0.9942743
# 100325516 0.10132712 0.9942743
# 100325517 0.14647714 0.8342301
# 100325518 0.10132712 0.9942743
# 100325519 0.10132712 0.9942743
# 100325520 0.10132712 0.9942743
# 100325521 0.10132712 0.9942743
# 100325522 0.10132712 0.9942743
# 100325523 0.10132712 0.9942743
# 100325524 0.10132712 0.9942743
# 100325525 0.10132712 0.9942743
# 100325526 0.10132712 0.9942743
# 100325527 0.10132712 0.9942743
# 100325528 0.10132712 0.9942743
# 100325529 0.10132712 0.9942743
# 100325530 0.10132712 0.9942743
# 100325531 0.10132712 0.9942743
# 100325532 0.10132712 0.9942743
# 100325533 0.11302149 0.9468390
# 100325534 0.10111784 0.9951722
# 100325535 0.09964788 1.0015319
# 100325536 0.10132712 0.9942743
# 100325537 0.10132712 0.9942743

# %%
print(paste0(snakemake@params$output_basedir, "/data.parquet"))
# Out:
# [1] "/s/project/rep/processed/training_results_v14/gtex_v8_old_dna/models/dna_only/watershed@train_simplecv.py#lightgbm/data.parquet"

# %%
write_dataset(melted_predictions_dt, paste0(snakemake@params$output_basedir, "/data.parquet"), partitioning="fold")
